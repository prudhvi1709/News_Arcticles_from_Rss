# %%
# Import necessary libraries
import feedparser
from sqlalchemy import create_engine, Column, String, Integer, DateTime, text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from celery import Celery
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import logging
import nltk

# %%
# Initialize Celery
celery = Celery('news_processing', broker='pyamqp://guest:guest@localhost//')
# Database setup
Base = declarative_base()
# Out:
# C:\Users\kprud\AppData\Local\Temp\ipykernel_21808\3065902628.py:4: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
class NewsArticle(Base):
    __tablename__ = 'news_articles'
    id = Column(Integer, primary_key=True)
    title = Column(String)
    content = Column(String)
    pub_date = Column(DateTime)
    source_url = Column(String)
    category = Column(String)

# %%
# Initialize database engine and create tables
engine = create_engine('postgresql://postgres:prudhvi@localhost/Rss', echo=True)
Base.metadata.create_all(bind=engine)
# Out:
# 2024-01-28 20:38:35,272 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-01-28 20:38:35,273 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-28 20:38:35,273 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-01-28 20:38:35,275 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-28 20:38:35,276 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-01-28 20:38:35,276 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-28 20:38:35,277 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 20:38:35,279 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-01-28 20:38:35,279 INFO sqlalchemy.engine.Engine [generated in 0.00064s] {'table_name': 'news_articles', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-01-28 20:38:35,282 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Initialize NLTK
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kprud\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def classify_category(content):
    # Add your NLP classification logic here
    # For example, a simple keyword-based approach
    if 'terrorism' in content.lower() or 'protest' in content.lower() or 'political unrest' in content.lower() or 'riot' in content.lower():
        return 'Terrorism/Protest/Political Unrest/Riot'
    elif 'positive' in content.lower() or 'uplifting' in content.lower():
        return 'Positive/Uplifting'
    elif 'natural disaster' in content.lower():
        return 'Natural Disasters'
    else:
        return 'Others'

# %%
def save_to_database(article, category):
    Session = sessionmaker(bind=engine)
    session = Session()

    # Check for duplicate articles
    if not session.query(NewsArticle).filter_by(title=article['title'], source_url=article['link']).first():
        # Save new article to the database
        new_article = NewsArticle(
            title=article['title'],
            content=article['content'],
            pub_date=article['published'],
            source_url=article['link'],
            category=category
        )
        session.add(new_article)
        session.commit()

# %%
# Celery task for processing news articles

def process_news_article(article):
    try:
        # Perform NLP processing to determine category
        category = classify_category(article['content'])
        print(category)
        # Update the database with the assigned category
        save_to_database(article, category)
    except Exception as e:
        logging.error(f"Error processing article: {str(e)}")

# %%
def parse_rss_feeds():
    rss_feeds = [
        'http://rss.cnn.com/rss/cnn_topstories.rss',
        'http://qz.com/feed',
        'http://feeds.foxnews.com/foxnews/politics',
        'http://feeds.reuters.com/reuters/businessNews',
        'http://feeds.feedburner.com/NewshourWorld',
        'https://feeds.bbci.co.uk/news/world/asia/india/rss.xml'
    ]

    for feed_url in rss_feeds:
        feed = feedparser.parse(feed_url)
        for entry in feed.entries:
            try:
                # Check if the 'published' key exists
                published = entry.published
            except AttributeError:
                try:
                    # If 'published' key does not exist, try using 'updated' key
                    published = entry.updated
                except AttributeError:
                    # If neither 'published' nor 'updated' exist, set a default value or handle it as needed
                    published = None

            try:
                # Check if the 'summary' key exists
                content = entry.summary
            except AttributeError:
                # If 'summary' key does not exist, use 'description' or other suitable field
                content = entry.get('description', '')

            # Send article to Celery queue for asynchronous processing
            process_news_article({
                'title': entry.title,
                'content': content,
                'published': published,
                'link': entry.link
            })

# %%
if __name__ == '__main__':
    # Run the feed parser script
    parse_rss_feeds()
# Out:
# Others
# 2024-01-28 21:10:54,362 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,363 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,364 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {'title_1': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced', 'source_url_1': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,377 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,378 INFO sqlalchemy.engine.Engine [generated in 0.00080s] {'title': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced', 'content': '', 'pub_date': 'Wed, 19 Apr 2023 12:44:51 GMT', 'source_url': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,379 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,382 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,383 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,384 INFO sqlalchemy.engine.Engine [cached since 0.02019s ago] {'title_1': 'Dominion still has pending lawsuits against election deniers such as Rudy Giuliani and Sidney Powell', 'source_url_1': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/h_8d51e3ae2714edaa0dace837305d03b8', 'param_1': 1}
# 2024-01-28 21:10:54,385 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,386 INFO sqlalchemy.engine.Engine [cached since 0.008921s ago] {'title': 'Dominion still has pending lawsuits against election deniers such as Rudy Giuliani and Sidney Powell', 'content': '', 'pub_date': None, 'source_url': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/h_8d51e3ae2714edaa0dace837305d03b8', 'category': 'Others'}
# 2024-01-28 21:10:54,386 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,388 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,389 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,390 INFO sqlalchemy.engine.Engine [cached since 0.02739s ago] {'title_1': 'Here are the 20 specific Fox broadcasts and tweets Dominion says were defamatory', 'source_url_1': 'https://www.cnn.com/2023/04/17/media/dominion-fox-news-allegations/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,393 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,393 INFO sqlalchemy.engine.Engine [cached since 0.01632s ago] {'title': 'Here are the 20 specific Fox broadcasts and tweets Dominion says were defamatory', 'content': "• Fox-Dominion trial delay 'is not unusual,' judge says\n• Fox News' defamation battle isn't stopping Trump's election lies", 'pub_date': 'Mon, 17 Apr 2023 16:01:11 GMT', 'source_url': 'https://www.cnn.com/2023/04/17/media/dominion-fox-news-allegations/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,394 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,396 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,397 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,398 INFO sqlalchemy.engine.Engine [cached since 0.03436s ago] {'title_1': "Judge in Fox News-Dominion defamation trial: 'The parties have resolved their case'", 'source_url_1': 'https://www.cnn.com/2023/04/18/media/fox-dominion-settlement/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,399 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,399 INFO sqlalchemy.engine.Engine [cached since 0.02276s ago] {'title': "Judge in Fox News-Dominion defamation trial: 'The parties have resolved their case'", 'content': 'The judge just announced in court that a settlement has been reached in the historic defamation case between Fox News and Dominion Voting Systems.', 'pub_date': 'Wed, 19 Apr 2023 08:28:17 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/media/fox-dominion-settlement/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,400 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,401 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,403 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,403 INFO sqlalchemy.engine.Engine [cached since 0.03942s ago] {'title_1': "'Difficult to say with a straight face': Tapper reacts to Fox News' statement on settlement", 'source_url_1': 'https://www.cnn.com/videos/politics/2023/04/18/jake-tapper-dominion-lawsuit-settlement-fox-news-statement-lead-vpx.cnn', 'param_1': 1}
# 2024-01-28 21:10:54,404 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,405 INFO sqlalchemy.engine.Engine [cached since 0.02833s ago] {'title': "'Difficult to say with a straight face': Tapper reacts to Fox News' statement on settlement", 'content': "A settlement has been reached in Dominion Voting Systems' defamation case against Fox News, the judge for the case announced. The network will pay more than $787 million to Dominion, a lawyer for the company said.", 'pub_date': 'Tue, 18 Apr 2023 21:17:44 GMT', 'source_url': 'https://www.cnn.com/videos/politics/2023/04/18/jake-tapper-dominion-lawsuit-settlement-fox-news-statement-lead-vpx.cnn', 'category': 'Others'}
# 2024-01-28 21:10:54,407 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,408 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,409 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,409 INFO sqlalchemy.engine.Engine [cached since 0.04638s ago] {'title_1': 'Millions in the US could face massive consequences unless McCarthy can navigate out of a debt trap he set for Biden', 'source_url_1': 'https://www.cnn.com/2023/04/18/politics/mccarthy-biden-debt-ceiling/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,412 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,412 INFO sqlalchemy.engine.Engine [cached since 0.03533s ago] {'title': 'Millions in the US could face massive consequences unless McCarthy can navigate out of a debt trap he set for Biden', 'content': '• DeSantis goes to Washington, a place he once despised, looking for support to take on Trump\n• Opinion: For the GOP to win, it must ditch Trump\n• Chris Christie mulling 2024 White House bid\n• Analysis: The fire next time has begun burning in Tennessee', 'pub_date': 'Tue, 18 Apr 2023 20:34:45 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/politics/mccarthy-biden-debt-ceiling/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,413 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,414 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,415 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,415 INFO sqlalchemy.engine.Engine [cached since 0.05235s ago] {'title_1': 'White homeowner accused of shooting a Black teen who rang his doorbell turns himself in to face criminal charges', 'source_url_1': 'https://www.cnn.com/2023/04/18/us/kansas-city-ralph-yarl-shooting-tuesday/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,417 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,419 INFO sqlalchemy.engine.Engine [cached since 0.04178s ago] {'title': 'White homeowner accused of shooting a Black teen who rang his doorbell turns himself in to face criminal charges', 'content': "• 'A major part of Ralph died': Aunt of teen shot after ringing wrong doorbell speaks\n• 20-year-old woman shot after friend turned into the wrong driveway in upstate New York, officials say", 'pub_date': 'Wed, 19 Apr 2023 04:29:05 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/us/kansas-city-ralph-yarl-shooting-tuesday/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,420 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,422 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,423 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,423 INFO sqlalchemy.engine.Engine [cached since 0.06001s ago] {'title_1': "Newly released video shows scene of Jeremy Renner's snowplow accident", 'source_url_1': 'https://www.cnn.com/videos/us/2023/04/18/jeremy-renner-snowplow-accident-bodycam-nc-melas-contd-vpx.cnn', 'param_1': 1}
# 2024-01-28 21:10:54,424 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,425 INFO sqlalchemy.engine.Engine [cached since 0.04847s ago] {'title': "Newly released video shows scene of Jeremy Renner's snowplow accident", 'content': 'Newly released body camera footage shows firefighters and sheriff\'s deputies rushing to help actor Jeremy Renner after a near-fatal snowplow accident in January. The "Avengers" actor broke more than 30 bones and suffered other severe injuries. CNN\'s Chloe Melas has more.', 'pub_date': 'Tue, 18 Apr 2023 14:09:43 GMT', 'source_url': 'https://www.cnn.com/videos/us/2023/04/18/jeremy-renner-snowplow-accident-bodycam-nc-melas-contd-vpx.cnn', 'category': 'Others'}
# 2024-01-28 21:10:54,425 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,427 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,429 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,429 INFO sqlalchemy.engine.Engine [cached since 0.06562s ago] {'title_1': 'Jake Gyllenhaal and Jamie Lee Curtis spent the Covid-19 lockdown together', 'source_url_1': 'https://www.cnn.com/2023/04/18/entertainment/jake-gyllenhaal-jamie-lee-curtis-pandemic-living/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,430 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,431 INFO sqlalchemy.engine.Engine [cached since 0.05475s ago] {'title': 'Jake Gyllenhaal and Jamie Lee Curtis spent the Covid-19 lockdown together', 'content': "It's sourdough bread and handstands for Jake Gyllenhaal and Jamie Lee Curtis.", 'pub_date': 'Tue, 18 Apr 2023 14:40:32 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/entertainment/jake-gyllenhaal-jamie-lee-curtis-pandemic-living/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,432 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,434 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,435 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,435 INFO sqlalchemy.engine.Engine [cached since 0.07193s ago] {'title_1': 'Toddler crawls through White House fence, prompts Secret Service response', 'source_url_1': 'https://www.cnn.com/2023/04/18/politics/white-house-toddler/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,436 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,437 INFO sqlalchemy.engine.Engine [cached since 0.06014s ago] {'title': 'Toddler crawls through White House fence, prompts Secret Service response', 'content': 'A tiny intruder infiltrated White House grounds Tuesday, prompting a swift response from the US Secret Service.', 'pub_date': 'Tue, 18 Apr 2023 17:38:16 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/politics/white-house-toddler/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,437 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,439 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,440 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,440 INFO sqlalchemy.engine.Engine [cached since 0.07685s ago] {'title_1': "Jamie Foxx remains hospitalized nearly a week after 'medical complication'", 'source_url_1': 'https://www.cnn.com/2023/04/17/entertainment/jamie-foxx-remains-hospitalized/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,441 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,441 INFO sqlalchemy.engine.Engine [cached since 0.06529s ago] {'title': "Jamie Foxx remains hospitalized nearly a week after 'medical complication'", 'content': 'Jamie Foxx remains hospitalized in Georgia nearly a week after his daughter revealed the actor experienced a "medical complication," a source with knowledge of the matter told CNN on Monday.', 'pub_date': 'Tue, 18 Apr 2023 00:27:07 GMT', 'source_url': 'https://www.cnn.com/2023/04/17/entertainment/jamie-foxx-remains-hospitalized/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,442 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,445 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,446 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,446 INFO sqlalchemy.engine.Engine [cached since 0.08257s ago] {'title_1': "A 13-year-old dies after participating in a Benadryl TikTok 'challenge'", 'source_url_1': 'https://www.cnn.com/2023/04/18/us/benadryl-tiktok-challenge-teen-death-wellness/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,447 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,447 INFO sqlalchemy.engine.Engine [cached since 0.0712s ago] {'title': "A 13-year-old dies after participating in a Benadryl TikTok 'challenge'", 'content': 'A 13-year-old in Ohio has died after "he took a bunch of Benadryl," trying a dangerous TikTok challenge that\'s circulating online, according to a CNN affiliate and a GoFundMe account from his family.', 'pub_date': 'Wed, 19 Apr 2023 15:01:06 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/us/benadryl-tiktok-challenge-teen-death-wellness/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,448 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,450 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,451 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,451 INFO sqlalchemy.engine.Engine [cached since 0.08763s ago] {'title_1': 'See pizza delivery guy take out suspect fleeing police', 'source_url_1': 'https://www.cnn.com/videos/us/2023/04/18/pizza-guy-trips-perp-moos-cprog-orig-bdk.cnn', 'param_1': 1}
# 2024-01-28 21:10:54,453 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,453 INFO sqlalchemy.engine.Engine [cached since 0.07634s ago] {'title': 'See pizza delivery guy take out suspect fleeing police', 'content': "Pizza guy delivers more than a pie, taking out a fleeing suspect. CNN's Jeanne Moos shows him putting his best foot forward.", 'pub_date': 'Tue, 18 Apr 2023 16:40:22 GMT', 'source_url': 'https://www.cnn.com/videos/us/2023/04/18/pizza-guy-trips-perp-moos-cprog-orig-bdk.cnn', 'category': 'Others'}
# 2024-01-28 21:10:54,454 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,455 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,455 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,456 INFO sqlalchemy.engine.Engine [cached since 0.09278s ago] {'title_1': 'Netflix is winding down its DVD business after 25 years', 'source_url_1': 'https://www.cnn.com/2023/04/18/media/netflix-dvd-red-envelopes/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,457 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,457 INFO sqlalchemy.engine.Engine [cached since 0.08112s ago] {'title': 'Netflix is winding down its DVD business after 25 years', 'content': 'Netflix is officially winding down the business that helped make it a household name.', 'pub_date': 'Tue, 18 Apr 2023 20:10:51 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/media/netflix-dvd-red-envelopes/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,458 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,459 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,461 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,461 INFO sqlalchemy.engine.Engine [cached since 0.09771s ago] {'title_1': "FTC chair Lina Khan warns AI could 'turbocharge' fraud and scams", 'source_url_1': 'https://www.cnn.com/2023/04/18/tech/lina-khan-ai-warning/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,463 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,463 INFO sqlalchemy.engine.Engine [cached since 0.08645s ago] {'title': "FTC chair Lina Khan warns AI could 'turbocharge' fraud and scams", 'content': 'Artificial intelligence tools such as ChatGPT could lead to a "turbocharging" of consumer harms including fraud and scams, and the US government has substantial authority to crack down on AI-driven consumer harms under existing law, members of the Federal Trade Commission said Tuesday.', 'pub_date': 'Tue, 18 Apr 2023 17:59:38 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/tech/lina-khan-ai-warning/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,464 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,465 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,466 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,466 INFO sqlalchemy.engine.Engine [cached since 0.1035s ago] {'title_1': 'Eating too much of these foods is driving the rise in type 2 diabetes, study says', 'source_url_1': 'https://www.cnn.com/2023/04/17/health/rise-type-2-diabetes-global-wellness/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,467 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,469 INFO sqlalchemy.engine.Engine [cached since 0.09187s ago] {'title': 'Eating too much of these foods is driving the rise in type 2 diabetes, study says', 'content': 'Gobbling up too many refined wheat and rice products, along with eating too few whole grains, is fueling the growth of new cases of type 2 diabetes worldwide, according to a new study that models data through 2018.', 'pub_date': 'Mon, 17 Apr 2023 16:02:46 GMT', 'source_url': 'https://www.cnn.com/2023/04/17/health/rise-type-2-diabetes-global-wellness/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,470 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,471 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,471 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,471 INFO sqlalchemy.engine.Engine [cached since 0.1086s ago] {'title_1': "ADHD medication abuse in schools is a 'wake-up call'", 'source_url_1': 'https://www.cnn.com/2023/04/18/health/teen-misuse-adhd-meds-wellness/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,473 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,473 INFO sqlalchemy.engine.Engine [cached since 0.09744s ago] {'title': "ADHD medication abuse in schools is a 'wake-up call'", 'content': "At some middle and high schools in the United States, 1 in 4 teens report they've abused prescription stimulants for attention deficit hyperactivity disorder during the year prior, a new study found.", 'pub_date': 'Tue, 25 Apr 2023 17:44:36 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/health/teen-misuse-adhd-meds-wellness/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,474 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,477 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,477 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,477 INFO sqlalchemy.engine.Engine [cached since 0.1141s ago] {'title_1': 'Apple CEO was presented with an original Macintosh. See his reaction', 'source_url_1': 'https://www.cnn.com/videos/tech/2023/04/18/apple-store-mumbai-india-ceo-tim-cook-vedika-sud-ovn-biz-ldn-vpx.cnn', 'param_1': 1}
# 2024-01-28 21:10:54,478 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,479 INFO sqlalchemy.engine.Engine [cached since 0.1023s ago] {'title': 'Apple CEO was presented with an original Macintosh. See his reaction', 'content': "CEO Tim Cook personally welcomed customers to the new Apple store in Mumbai as the tech company opens its first retail stores in India. CNN's Vedika Sud reports.", 'pub_date': 'Tue, 18 Apr 2023 09:17:25 GMT', 'source_url': 'https://www.cnn.com/videos/tech/2023/04/18/apple-store-mumbai-india-ceo-tim-cook-vedika-sud-ovn-biz-ldn-vpx.cnn', 'category': 'Others'}
# 2024-01-28 21:10:54,479 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,482 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,482 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,482 INFO sqlalchemy.engine.Engine [cached since 0.1191s ago] {'title_1': 'Democrats bash Justice Clarence Thomas but their plan to investigate ethics allegations is unclear', 'source_url_1': 'https://www.cnn.com/2023/04/18/politics/clarence-thomas-ethics-democrats/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,483 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,483 INFO sqlalchemy.engine.Engine [cached since 0.1073s ago] {'title': 'Democrats bash Justice Clarence Thomas but their plan to investigate ethics allegations is unclear', 'content': 'Senate Democrats railed against Justice Clarence Thomas on Tuesday amid reports that the Supreme Court conservative failed to disclose luxury travel, gifts and a real estate transaction involving a GOP megadonor, but their plan to investigate the conservative jurist remains unclear.', 'pub_date': 'Tue, 18 Apr 2023 20:29:46 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/politics/clarence-thomas-ethics-democrats/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,485 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,486 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,487 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,487 INFO sqlalchemy.engine.Engine [cached since 0.1241s ago] {'title_1': "Russia is 'going backwards' in equipment and deploying post WWII-era tanks, according to Western officials", 'source_url_1': 'https://www.cnn.com/europe/live-news/russia-ukraine-war-news-04-18-23/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,488 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,489 INFO sqlalchemy.engine.Engine [cached since 0.1126s ago] {'title': "Russia is 'going backwards' in equipment and deploying post WWII-era tanks, according to Western officials", 'content': '• Jailed Wall Street Journal reporter Evan Gershkovich denied detention appeal in Moscow\n• Putin visits Russian troops at military headquarters in Kherson\n• Watch moment WSJ journalist appears in Russian court', 'pub_date': None, 'source_url': 'https://www.cnn.com/europe/live-news/russia-ukraine-war-news-04-18-23/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,489 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,492 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,492 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,493 INFO sqlalchemy.engine.Engine [cached since 0.1291s ago] {'title_1': 'Two Russians claiming to be former Wagner commanders admit killing children and civilians in Ukraine', 'source_url_1': 'https://www.cnn.com/2023/04/17/europe/wagner-commanders-russia-kill-children-intl-hnk/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,493 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,494 INFO sqlalchemy.engine.Engine [cached since 0.1178s ago] {'title': 'Two Russians claiming to be former Wagner commanders admit killing children and civilians in Ukraine', 'content': 'Two Russian men who claim to be former Wagner Group commanders have told a human rights activist that they killed children and civilians during their time in Ukraine.', 'pub_date': 'Tue, 18 Apr 2023 19:07:52 GMT', 'source_url': 'https://www.cnn.com/2023/04/17/europe/wagner-commanders-russia-kill-children-intl-hnk/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,496 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,497 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,499 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,499 INFO sqlalchemy.engine.Engine [cached since 0.1354s ago] {'title_1': "'My stomach is hurting from laughing': Hear panelist's reaction to DeSantis' threat to Disney", 'source_url_1': 'https://www.cnn.com/videos/business/2023/04/18/desantis-disney-competition-panel-reax-pt-vpx.cnn', 'param_1': 1}
# 2024-01-28 21:10:54,500 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,501 INFO sqlalchemy.engine.Engine [cached since 0.1241s ago] {'title': "'My stomach is hurting from laughing': Hear panelist's reaction to DeSantis' threat to Disney", 'content': 'CNN panelists react to Florida Gov. Ron DeSantis floating the idea of building a competing theme park next to Disney World in Orlando.', 'pub_date': 'Tue, 18 Apr 2023 03:24:56 GMT', 'source_url': 'https://www.cnn.com/videos/business/2023/04/18/desantis-disney-competition-panel-reax-pt-vpx.cnn', 'category': 'Others'}
# 2024-01-28 21:10:54,502 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,503 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,503 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,504 INFO sqlalchemy.engine.Engine [cached since 0.1407s ago] {'title_1': 'GOP prepared to block vote to replace Feinstein on Senate Judiciary', 'source_url_1': 'https://www.cnn.com/2023/04/18/politics/schumer-senate-feinstein-vote-cardin/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,505 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,505 INFO sqlalchemy.engine.Engine [cached since 0.1288s ago] {'title': 'GOP prepared to block vote to replace Feinstein on Senate Judiciary', 'content': 'Senate Majority Leader Chuck Schumer said on Tuesday that he hopes to replace Democratic Sen. Dianne Feinstein on the Senate Judiciary Committee with Sen. Ben Cardin of Maryland and aims to set up a floor vote on the issue this afternoon, which Republicans are expected to block.', 'pub_date': 'Tue, 18 Apr 2023 22:03:13 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/politics/schumer-senate-feinstein-vote-cardin/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,506 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,508 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,509 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,509 INFO sqlalchemy.engine.Engine [cached since 0.1458s ago] {'title_1': 'Oklahoma governor calls on officials to resign over recording of racist and threatening remarks', 'source_url_1': 'https://www.cnn.com/2023/04/18/us/mccurtain-county-oklahoma-officials-recording/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,510 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,511 INFO sqlalchemy.engine.Engine [cached since 0.1344s ago] {'title': 'Oklahoma governor calls on officials to resign over recording of racist and threatening remarks', 'content': '', 'pub_date': 'Tue, 18 Apr 2023 17:33:17 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/us/mccurtain-county-oklahoma-officials-recording/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,511 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,514 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,516 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,516 INFO sqlalchemy.engine.Engine [cached since 0.1529s ago] {'title_1': 'McCarthy slams Biden in handling of US debt', 'source_url_1': 'https://www.cnn.com/videos/politics/2023/04/18/kevin-mccarthy-wall-street-speech-debt-ceiling-biden-economy-vpx.cnn', 'param_1': 1}
# 2024-01-28 21:10:54,518 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,518 INFO sqlalchemy.engine.Engine [cached since 0.1418s ago] {'title': 'McCarthy slams Biden in handling of US debt', 'content': 'House Speaker Kevin McCarthy traveled to Wall Street on Monday to deliver a fresh warning that the House GOP majority will refuse to lift a cap on government borrowing unless Biden agrees to spending cuts that would effectively neutralize his domestic agenda.', 'pub_date': 'Tue, 18 Apr 2023 22:03:01 GMT', 'source_url': 'https://www.cnn.com/videos/politics/2023/04/18/kevin-mccarthy-wall-street-speech-debt-ceiling-biden-economy-vpx.cnn', 'category': 'Others'}
# 2024-01-28 21:10:54,519 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,521 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,522 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,522 INFO sqlalchemy.engine.Engine [cached since 0.1592s ago] {'title_1': 'US warns Russia not to touch American nuclear technology at Ukrainian nuclear plant', 'source_url_1': 'https://www.cnn.com/2023/04/18/politics/us-warns-russia-zaporizhzhia-nuclear-plant/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,523 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,523 INFO sqlalchemy.engine.Engine [cached since 0.1475s ago] {'title': 'US warns Russia not to touch American nuclear technology at Ukrainian nuclear plant', 'content': "The US has sensitive nuclear technology at a nuclear power plant inside Ukraine and is warning Russia not to touch it, according to a letter the US Department of Energy sent to Russia's state-owned nuclear energy firm Rosatom last month.", 'pub_date': 'Wed, 19 Apr 2023 08:35:33 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/politics/us-warns-russia-zaporizhzhia-nuclear-plant/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,525 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,527 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,527 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,528 INFO sqlalchemy.engine.Engine [cached since 0.1645s ago] {'title_1': 'Repeated gunshots fired on live TV as ex-lawmaker shot by assassins', 'source_url_1': 'https://www.cnn.com/videos/world/2023/04/18/india-ex-lawmaker-atiq-ahmed-assassination-sud-pkg-contd-ovn-intl-hnk-vpx.cnn', 'param_1': 1}
# 2024-01-28 21:10:54,529 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,530 INFO sqlalchemy.engine.Engine [cached since 0.1537s ago] {'title': 'Repeated gunshots fired on live TV as ex-lawmaker shot by assassins', 'content': "Atiq Ahmed, a former lawmaker in India's parliament, convicted of kidnapping, was shot dead along with his brother while police were escorting them for a medical check-up in a slaying caught on live television on Saturday. CNN's Vedika Sud reports.", 'pub_date': 'Tue, 18 Apr 2023 09:41:42 GMT', 'source_url': 'https://www.cnn.com/videos/world/2023/04/18/india-ex-lawmaker-atiq-ahmed-assassination-sud-pkg-contd-ovn-intl-hnk-vpx.cnn', 'category': 'Others'}
# 2024-01-28 21:10:54,531 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,532 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,534 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:54,534 INFO sqlalchemy.engine.Engine [cached since 0.1705s ago] {'title_1': 'FDA clears the way for additional bivalent boosters for certain vulnerable individuals', 'source_url_1': 'https://www.cnn.com/2023/04/18/health/fda-bivalent-booster-additional-doses/index.html', 'param_1': 1}
# 2024-01-28 21:10:54,535 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:54,536 INFO sqlalchemy.engine.Engine [cached since 0.1588s ago] {'title': 'FDA clears the way for additional bivalent boosters for certain vulnerable individuals', 'content': "The U.S. Food and Drug Administration amended the terms of its emergency use authorizations for the Pfizer and Moderna bivalent vaccines on Tuesday, allowing people ages 65 and older and certain people with weakened immunity to get additional doses before this fall's vaccination campaigns.", 'pub_date': 'Tue, 18 Apr 2023 15:09:15 GMT', 'source_url': 'https://www.cnn.com/2023/04/18/health/fda-bivalent-booster-additional-doses/index.html', 'category': 'Others'}
# 2024-01-28 21:10:54,536 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:54,538 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:54,539 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# ...
# 2024-01-28 21:10:58,330 INFO sqlalchemy.engine.Engine [cached since 3.953s ago] {'title': "What Rahul Gandhi's march means for India election", 'content': "The Congress leader's cross-country march began with hope, but analysts doubt its electoral impact.", 'pub_date': 'Mon, 15 Jan 2024 08:38:23 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67911170?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,331 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,334 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,335 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,336 INFO sqlalchemy.engine.Engine [cached since 3.972s ago] {'title_1': 'Agatha Christie: The Indian hotel murder that inspired the queen of crime', 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67943375?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,337 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,338 INFO sqlalchemy.engine.Engine [cached since 3.962s ago] {'title': 'Agatha Christie: The Indian hotel murder that inspired the queen of crime', 'content': "The sensational case, which made global headlines, is said to have influenced Christie's first book.", 'pub_date': 'Sat, 13 Jan 2024 22:26:16 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67943375?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,339 INFO sqlalchemy.engine.Engine COMMIT
# Terrorism/Protest/Political Unrest/Riot
# 2024-01-28 21:10:58,342 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,343 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,344 INFO sqlalchemy.engine.Engine [cached since 3.981s ago] {'title_1': "Bengaluru: Why English is dividing people in India's Silicon Valley", 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67889621?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,346 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,346 INFO sqlalchemy.engine.Engine [cached since 3.97s ago] {'title': "Bengaluru: Why English is dividing people in India's Silicon Valley", 'content': 'Kannada-language protesters recently hit the headlines for tearing down English billboards in Bengaluru.', 'pub_date': 'Fri, 12 Jan 2024 00:20:40 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67889621?at_medium=RSS&at_campaign=KARANGA', 'category': 'Terrorism/Protest/Political Unrest/Riot'}
# 2024-01-28 21:10:58,348 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,351 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,352 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,352 INFO sqlalchemy.engine.Engine [cached since 3.989s ago] {'title_1': "Bihar men conned by 'impregnating women' job scam", 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67860456?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,354 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,354 INFO sqlalchemy.engine.Engine [cached since 3.978s ago] {'title': "Bihar men conned by 'impregnating women' job scam", 'content': 'Scammers in Bihar state promised to pay huge sums of money to men to get childless women pregnant.', 'pub_date': 'Wed, 10 Jan 2024 00:00:22 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67860456?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,355 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,357 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,358 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,359 INFO sqlalchemy.engine.Engine [cached since 3.996s ago] {'title_1': "Maldives: Maldivians debate India's 'boycott' of their nation", 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67942642?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,360 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,361 INFO sqlalchemy.engine.Engine [cached since 3.985s ago] {'title': "Maldives: Maldivians debate India's 'boycott' of their nation", 'content': "Tensions have escalated after three Maldivian ministers made derogatory comments about India's PM Modi.", 'pub_date': 'Thu, 11 Jan 2024 07:28:52 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67942642?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,363 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,365 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,366 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,368 INFO sqlalchemy.engine.Engine [cached since 4.004s ago] {'title_1': 'Plane gets jammed under bridge in India', 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67843833?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,369 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,370 INFO sqlalchemy.engine.Engine [cached since 3.993s ago] {'title': 'Plane gets jammed under bridge in India', 'content': 'The scrap fuselage was on its way to Assam from Mumbai on a lorry when it got stuck.', 'pub_date': 'Fri, 29 Dec 2023 23:17:00 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67843833?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,370 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,372 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,373 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,373 INFO sqlalchemy.engine.Engine [cached since 4.01s ago] {'title_1': 'Intruder jumps on table in Indian parliament', 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67700660?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,374 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,375 INFO sqlalchemy.engine.Engine [cached since 3.999s ago] {'title': 'Intruder jumps on table in Indian parliament', 'content': "Lawmakers said two men jumped into the well of the house from the visitors' gallery.", 'pub_date': 'Wed, 13 Dec 2023 09:49:30 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67700660?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,375 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,378 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,379 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,380 INFO sqlalchemy.engine.Engine [cached since 4.016s ago] {'title_1': 'Moment worker is pulled from collapsed tunnel', 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67552409?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,382 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,383 INFO sqlalchemy.engine.Engine [cached since 4.006s ago] {'title': 'Moment worker is pulled from collapsed tunnel', 'content': 'Fourty-one Indian workers are finally rescued from a tunnel that partially caved in after a landslide.', 'pub_date': 'Tue, 28 Nov 2023 15:13:21 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67552409?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,384 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,386 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,387 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,388 INFO sqlalchemy.engine.Engine [cached since 4.025s ago] {'title_1': 'First video of trapped tunnel workers in India', 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67482786?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,389 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,391 INFO sqlalchemy.engine.Engine [cached since 4.014s ago] {'title': 'First video of trapped tunnel workers in India', 'content': 'Rescuers have shared a video of the 41 workers who have been trapped inside a tunnel since 12 November.', 'pub_date': 'Tue, 21 Nov 2023 05:58:33 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67482786?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,392 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,393 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,394 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,395 INFO sqlalchemy.engine.Engine [cached since 4.031s ago] {'title_1': 'Andhra Pradesh: Drone footage shows aftermath of deadly India train crash', 'source_url_1': 'https://www.bbc.co.uk/news/world-asia-india-67258761?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,396 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,397 INFO sqlalchemy.engine.Engine [cached since 4.02s ago] {'title': 'Andhra Pradesh: Drone footage shows aftermath of deadly India train crash', 'content': 'A preliminary investigation has found that "human error" led to the collision, officials say.', 'pub_date': 'Mon, 30 Oct 2023 06:08:55 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-asia-india-67258761?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,398 INFO sqlalchemy.engine.Engine COMMIT
# Others
# 2024-01-28 21:10:58,400 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-28 21:10:58,401 INFO sqlalchemy.engine.Engine SELECT news_articles.id AS news_articles_id, news_articles.title AS news_articles_title, news_articles.content AS news_articles_content, news_articles.pub_date AS news_articles_pub_date, news_articles.source_url AS news_articles_source_url, news_articles.category AS news_articles_category
# FROM news_articles
# WHERE news_articles.title = %(title_1)s AND news_articles.source_url = %(source_url_1)s
#  LIMIT %(param_1)s
# 2024-01-28 21:10:58,401 INFO sqlalchemy.engine.Engine [cached since 4.039s ago] {'title_1': 'India flash floods: More than 100 missing in Sikkim state', 'source_url_1': 'https://www.bbc.co.uk/news/world-67015721?at_medium=RSS&at_campaign=KARANGA', 'param_1': 1}
# 2024-01-28 21:10:58,404 INFO sqlalchemy.engine.Engine INSERT INTO news_articles (title, content, pub_date, source_url, category) VALUES (%(title)s, %(content)s, %(pub_date)s, %(source_url)s, %(category)s) RETURNING news_articles.id
# 2024-01-28 21:10:58,404 INFO sqlalchemy.engine.Engine [cached since 4.028s ago] {'title': 'India flash floods: More than 100 missing in Sikkim state', 'content': 'Hundreds of search and rescue officers have been deployed across the state of Sikkim.', 'pub_date': 'Thu, 05 Oct 2023 07:25:09 GMT', 'source_url': 'https://www.bbc.co.uk/news/world-67015721?at_medium=RSS&at_campaign=KARANGA', 'category': 'Others'}
# 2024-01-28 21:10:58,405 INFO sqlalchemy.engine.Engine COMMIT
